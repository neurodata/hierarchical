# %%
import numpy as np
import pandas as pd

from PIL import Image

from skimage.transform import resize
from proglearn.transformers import TreeClassificationTransformer as transformer
from proglearn.voters import TreeClassificationVoter as voter

import torchvision

import os

# %%
torchvision.datasets.CIFAR100(, train=True, transform=None, target_transform=None, download=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-87af3f29b137> in <module>
# ----> 1 torchvision.datasets.CIFAR100(root, train=True, transform=None, target_transform=None, download=True)
#
# NameError: name 'root' is not defined

# %%
# Grab patient ids associated with training data

patient_ids_train = []

for i, f in enumerate(os.listdir(train_path)):
    patient_ids_train.append(str(f).split('patient')[1])

# %%
# Turn the .jpgs provided into arrays

as_array = True

if not as_array:
    images_as_arrays = np.zeros((len(patient_ids_train), 256, 256))

    study1 = 'study1'+ '/'
    frontal = 'view1_frontal.jpg'

    for i, f in enumerate(patient_ids_train):
        temp_path = train_path + '/' + 'patient' + patient_ids_train[i] + '/'

        try: 
            temp_pic = Image.open(temp_path + study1 + frontal)
            temp_array = np.array(temp_pic.getdata()).reshape(temp_pic.size[0], temp_pic.size[1])

            images_as_arrays[i] = resize(temp_array, (256, 256))
        except:
            print(i, f)
    as_array=True

# %%
train_csv = pd.read_csv(filepath + 'train.csv')
train_csv.head()
# Out:
#                                                 Path     Sex  Age  \
# 0  CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1  CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3  CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4  CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
#
#   Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# 0         Frontal    AP         1.0                         NaN           NaN
# 1         Frontal    AP         NaN                         NaN          -1.0
# 2         Frontal    AP         NaN                         NaN           NaN
# 3         Lateral   NaN         NaN                         NaN           NaN
# 4         Frontal    AP         NaN                         NaN           NaN
#
#    Lung Opacity  Lung Lesion  Edema  Consolidation  Pneumonia  Atelectasis  \
# ...

# %%
# Estimate posteriors for "coarse" class

# %%
# Estimate posteriors for "fine" classes
